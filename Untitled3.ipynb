# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyananda-Pradeep/s2colab/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loop-for,while
#for-loop(iteration)
#for var in seq:
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
list[1,2,3,4]
hasi=[1,2,3,4]
print(hasi)
# Out:
# [1, 2, 3, 4]

# %%
list[1,2,3,4]
hasi=[1,2,3,4]
print(hasi[3])
# Out:
# 4

# %%
list[1,2,3,4]
hasi=[1,2,3,4]
print(hasi)
hasi.append(5)
print(hasi)
hasi.remove(1)
print(hasi)
hasi.insert(2,5)
print(hasi)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 5]
# [2, 3, 4, 5]
# [2, 3, 5, 4, 5]

# %%
animal=["cat","dog","rabbit","elephant",]
print(animal)
animal.insert(3,"giraffe")
print(animal)
animal.remove("elephant")
print(animal)
# Out:
# ['cat', 'dog', 'rabbit', 'elephant']
# ['cat', 'dog', 'rabbit', 'giraffe', 'elephant']
# ['cat', 'dog', 'rabbit', 'giraffe']

# %%
#tapple.imovable list{}
a={1,2,3,4}
print(a)
# Out:
# {1, 2, 3, 4}

# %%
#loop-for,while
#for-loop(iteration)
#for var in seq:
for i in ["a","b","c"]:
  print(i)
# Out:
# a
# b
# c
