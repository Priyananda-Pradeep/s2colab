# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyananda-Pradeep/s2colab/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#keywordargument
#dictionaryinpython
#hasi={key:value}

# %%
#dictioary
priya={"name":"priyananda pradeep","age":"21","fav movie":"ponman"}
print(priya)
# Out:
# {'name': 'priyananda pradeep', 'age': '21', 'fav movie': 'ponman'}

# %%
#dictioary
priya={"name":"priyananda pradeep","age":"21","fav movie":"ponman"}
print(priya["name"])
# Out:
# priyananda pradeep

# %%
bmf={"birds":["crow","hen","peacock","pegion","kingfisher"],"food":["rice","curry","bun","bread","mandi"],"mammals":["dog","cat","pig","goat","cow"]}
print(bmf["birds"])
print(bmf["food"])
print(bmf["mammals"])
# Out:
# ['crow', 'hen', 'peacock', 'pegion', 'kingfisher']
# ['rice', 'curry', 'bun', 'bread', 'mandi']
# ['dog', 'cat', 'pig', 'goat', 'cow']

# %%
def hasi(**days)
 print()

# %%
def pqy(name,age):
  print(name,age)

# %%
pqy(name="priya",age="21")
# Out:
# priya 21

# %%
def cbs(**kwargs):
  print(kwargs)
cbs(name="priya",age="21",place="kozhikode")
# Out:
# {'name': 'priya', 'age': '21', 'place': 'kozhikode'}
